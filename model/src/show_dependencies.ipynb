# %%
import ast
import os

# %%
class FunctionDependencyVisitor(ast.NodeVisitor):
    def __init__(self):
        self.functions = {}
        self.current_function = None

    def visit_FunctionDef(self, node):
        self.current_function = node.name
        self.functions[node.name] = {
            'calls': [],
            'lineno': node.lineno,
            'col_offset': node.col_offset
        }
        self.generic_visit(node)
        self.current_function = None

    def visit_Call(self, node):
        if self.current_function:
            func_name = self._get_call_name(node)
            if func_name:
                self.functions[self.current_function]['calls'].append(func_name)
        self.generic_visit(node)

    def _get_call_name(self, node):
        if isinstance(node.func, ast.Name):
            return node.func.id
        elif isinstance(node.func, ast.Attribute):
            return node.func.attr
        return None

def parse_python_files(directory):
    visitor = FunctionDependencyVisitor()
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".py"):
                file_path = os.path.join(root, file)
                with open(file_path, "r") as source:
                    tree = ast.parse(source.read(), filename=file_path)
                    visitor.visit(tree)
    return visitor.functions

# %%
import networkx as nx

def build_dependency_graph(functions):
    G = nx.DiGraph()
    for func, details in functions.items():
        G.add_node(func, lineno=details['lineno'], col_offset=details['col_offset'])
        for called_func in details['calls']:
            G.add_edge(func, called_func)
    return G

# %%
parse_python_files("./pyrenew/")
# Out:
# {'predict': {'calls': ['matmul', 'transform'], 'lineno': 46, 'col_offset': 4},
#  'sample': {'calls': ['tensor',
#    'tensor',
#    'zeros',
#    'range',
#    'sample',
#    'Normal'],
#   'lineno': 25,
#   'col_offset': 4},
#  '__init__': {'calls': [], 'lineno': 11, 'col_offset': 4},
#  '__repr__': {'calls': [], 'lineno': 21, 'col_offset': 4},
#  'spread_draws': {'calls': ['spread_draws', 'get_samples'],
#   'lineno': 444,
#   'col_offset': 4},
#  'plot_posterior': {'calls': ['plot_posterior', 'spread_draws'],
#   'lineno': 460,
#   'col_offset': 4},
#  'validate_discrete_dist_vector': {'calls': ['flatten',
#    'all',
#    'ValueError',
#    'isclose',
#    'sum',
#    'tensor',
#    'ValueError'],
#   'lineno': 4,
#   'col_offset': 0},
#  'reverse_discrete_dist_vector': {'calls': ['flip'],
#   'lineno': 69,
#   'col_offset': 0},
#  'new_double_convolve_scanner': {'calls': [], 'lineno': 26, 'col_offset': 0},
#  '_new_scanner': {'calls': ['t1',
#    'dot',
#    't2',
#    'dot',
#    'cat',
#    'unsqueeze',
#    'item'],
#   'lineno': 36,
#   'col_offset': 4},
#  'torch_convolve_scanner': {'calls': [], 'lineno': 50, 'col_offset': 0},
#  '_scanner': {'calls': ['len',
#    'len',
#    'tensor',
#    'tensor',
#    't1',
#    'dot',
#    't2',
#    'dot',
#    'dim',
#    'unsqueeze',
#    'cat',
#    'item'],
#   'lineno': 159,
#   'col_offset': 4},
#  'torch_double_convolve_scanner': {'calls': [],
#   'lineno': 132,
#   'col_offset': 0},
#  'torch_scan': {'calls': ['isinstance', 'f', 'f', 'append', 'tensor', 'stack'],
#   'lineno': 183,
#   'col_offset': 0},
#  'torch_convolve': {'calls': ['len',
#    'len',
#    'view',
#    'view',
#    'flip',
#    'pad',
#    'conv1d',
#    'ValueError',
#    'conv1d',
#    'view'],
#   'lineno': 223,
#   'col_offset': 0},
#  '_assert_sample_and_rtype': {'calls': ['Exception',
#    'isinstance',
#    'Exception',
#    'Exception',
#    'get',
#    'get_type_hints',
#    'Exception',
#    'isinstance',
#    'rettype',
#    'Exception',
#    'Exception'],
#   'lineno': 20,
#   'col_offset': 0},
#  'set_timeseries': {'calls': ['isinstance', 'type', 'isinstance', 'type'],
#   'lineno': 126,
#   'col_offset': 4},
#  'validate': {'calls': ['_assert_sample_and_rtype',
#    '_assert_sample_and_rtype',
#    '_assert_sample_and_rtype'],
#   'lineno': 95,
#   'col_offset': 4},
#  '_init_model': {'calls': ['dict', 'dict', 'NUTS', 'MCMC'],
#   'lineno': 337,
#   'col_offset': 4},
#  'run': {'calls': ['_init_model', 'randint', 'run'],
#   'lineno': 382,
#   'col_offset': 4},
#  'print_summary': {'calls': ['summary'], 'lineno': 422, 'col_offset': 4},
#  'posterior_predictive': {'calls': ['ValueError',
#    'randint',
#    'Predictive',
#    'get_samples',
#    'predictive'],
#   'lineno': 484,
#   'col_offset': 4},
#  'prior_predictive': {'calls': ['randint', 'Predictive', 'predictive'],
#   'lineno': 524,
#   'col_offset': 4},
#  'pad_to_match': {'calls': ['size',
#    'size',
#    'abs',
#    'ValueError',
#    'ValueError',
#    'pad',
#    'pad'],
#   'lineno': 9,
#   'col_offset': 0},
#  'pad_x_to_match_y': {'calls': ['pad_to_match'],
#   'lineno': 40,
#   'col_offset': 0},
#  '__call__': {'calls': ['seed_infections'], 'lineno': 43, 'col_offset': 4},
#  'get_leslie_matrix': {'calls': ['validate_discrete_dist_vector',
#    'numel',
#    'cat',
#    'eye',
#    'unsqueeze',
#    'zeros',
#    'cat',
#    'unsqueeze'],
#   'lineno': 15,
#   'col_offset': 0},
#  'get_asymptotic_growth_rate_and_age_dist': {'calls': ['get_leslie_matrix',
#    'eig',
#    'argmax',
#    'abs',
#    'real',
#    'real',
#    'any',
#    'ValueError',
#    'sum',
#    'item'],
#   'lineno': 28,
#   'col_offset': 0},
#  'get_stable_age_distribution': {'calls': ['get_asymptotic_growth_rate_and_age_dist'],
#   'lineno': 47,
#   'col_offset': 0},
#  'get_asymptotic_growth_rate': {'calls': ['get_asymptotic_growth_rate_and_age_dist'],
#   'lineno': 53,
#   'col_offset': 0},
#  '__eq__': {'calls': ['isinstance'], 'lineno': 17, 'col_offset': 4},
#  '_inverse': {'calls': [], 'lineno': 23, 'col_offset': 4},
#  'log_abs_det_jacobian': {'calls': ['zeros_like'],
#   'lineno': 26,
#   'col_offset': 4},
#  'event_dim': {'calls': [], 'lineno': 30, 'col_offset': 4},
#  'check': {'calls': ['is_tensor'], 'lineno': 37, 'col_offset': 4},
#  'ScaledLogitTransform': {'calls': ['ComposeTransform',
#    'AffineTransform',
#    'SigmoidTransform'],
#   'lineno': 40,
#   'col_offset': 0},
#  'load_generation_interval': {'calls': ['read_csv', 'files'],
#   'lineno': 8,
#   'col_offset': 0},
#  'load_wastewater': {'calls': ['read_csv', 'files'],
#   'lineno': 13,
#   'col_offset': 0},
#  'load_infection_admission_interval': {'calls': ['read_csv', 'files'],
#   'lineno': 8,
#   'col_offset': 0},
#  'size': {'calls': [], 'lineno': 91, 'col_offset': 4},
#  'compute_infections_from_rt': {'calls': ['torch_convolve_scanner',
#    'IdentityTransform',
#    'torch_scan'],
#   'lineno': 8,
#   'col_offset': 0},
#  'logistic_susceptibility_adjustment': {'calls': ['exp'],
#   'lineno': 20,
#   'col_offset': 0},
#  'compute_infections_from_rt_with_feedback': {'calls': ['torch_double_convolve_scanner',
#    'zeros_like',
#    'zeros_like',
#    'torch_scan'],
#   'lineno': 27,
#   'col_offset': 0},
#  'seed_infections': {'calls': ['numel',
#    'ValueError',
#    'numel',
#    'sample',
#    'size',
#    'ValueError',
#    'arange',
#    'exp'],
#   'lineno': 109,
#   'col_offset': 4},
#  'autoreg_process': {'calls': ['cat'], 'lineno': 124, 'col_offset': 4}}

# %%
def find_all_dependencies(G, function_name):
    dependencies = nx.descendants(G, function_name)
    return dependencies

# Example function to show dependencies
def show_dependencies(directory, function_name):
    functions = parse_python_files(directory)
    G = build_dependency_graph(functions)
    dependencies = find_all_dependencies(G, function_name)
    print(f"Dependencies for {function_name}: {dependencies}")

# Integration
show_dependencies("./test/", "test_glm_prediction")
# Out:
# Dependencies for test_glm_prediction: {'assert_close', 'matmul', 'predict', 'zeros', 'set_rng_seed', 'GLMPrediction', 'sample', 'expand', 'isinstance', 'Uniform', 'tensor', 'Normal', 'IdentityTransform', 'keys'}

# %%
# !pwd
# Out:
# /Users/krue284/Local Files/ASKEM/multisignal-epi-inference/model/src
